# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('data/df1.csv',index_col=0)

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df['A'].plot.hist()

# %%
df2 = pd.read_csv('data/df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df['A'].plot.hist(edgecolor='k')

# %%
df['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df['A'].plot.hist(bins=100, edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df['A'].plot.hist(bins=20, edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df['A'].plot.hist(grid=True)

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.line(y='a')

# %%
df2.plot.line(y=['a','b','c'],figsize=(12,5))

# %%
df.plot.scatter(x='A',y='B')

# %%
df.plot.scatter(x='A',y='B', c='C', cmap='coolwarm', s=df['C']*50)
# Out:
# /home/ma/.bin/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df2.boxplot()

# %%
df2['a'].plot.kde()

# %%
df2.plot.kde()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.scatter(x='a',y='b')

# %%
df
# Out:
#             a         b
# 0    1.270933 -0.013922
# 1   -0.637317  0.944087
# 2   -0.533618 -1.668343
# 3   -1.259694  0.923505
# 4    0.893487 -0.242506
# ..        ...       ...
# 995  0.601972 -0.393414
# 996  0.246512 -0.523805
# 997 -0.336340  0.592842
# 998 -0.658151 -0.519620
# 999  1.101104 -2.250390
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot()

# %%
df2['c'].plot()

# %%
df2['c'].plot.line(figsize=(20,5),ls=':',c='red',lw=5)

# %%
title = 'My Plot Title'
xlabel = "MY X data"
ylabel = "My Y data"

# %%
ax = df2['c'].plot.line(figsize=(12,5))
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'My Y data'), Text(0.5, 0, 'MY X data')]

# %%
ax = df2['c'].plot.line(figsize=(12,5), title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'My Y data'), Text(0.5, 0, 'MY X data')]

# %%
ax = df2.plot()
ax.legend(loc=0,bbox_to_anchor=(1.0, 1.0))
