# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/city_income2.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-22-a8ba3d396d91> in <module>
# ----> 1 df = pd.read_csv('../input/city_income2.csv')
#
# ~/.bin/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df.head()
# Out:
#       調査年 コード     調査年  地域 コード       地域  /項目  C120110_課税対象所得【千円】  注釈  \
# 0  2018100000  2018年度    1100  北海道 札幌市  NaN          2765204529 NaN
# 1  2018100000  2018年度    1202  北海道 函館市  NaN           309138713 NaN
# 2  2018100000  2018年度    1203  北海道 小樽市  NaN           121623457 NaN
# 3  2018100000  2018年度    1204  北海道 旭川市  NaN           398298889 NaN
# 4  2018100000  2018年度    1205  北海道 室蘭市  NaN           102405024 NaN
#
#    C120120_納税義務者数（所得割）【人】  注釈.1
# 0                  878047   NaN
# 1                  110159   NaN
# 2                   47519   NaN
# 3                  141786   NaN
# 4                   35533   NaN

# %%
df.shape
# Out:
# (1741, 9)

# %%
df.columns = ['code', 'year','dist_code','koumoku', 'dist_name', 'income','momo','num_of_sample','misc']

# %%
df.head()
# Out:
#          code    year  dist_code  koumoku  dist_name      income  momo  \
# 0  2018100000  2018年度       1100  北海道 札幌市        NaN  2765204529   NaN
# 1  2018100000  2018年度       1202  北海道 函館市        NaN   309138713   NaN
# 2  2018100000  2018年度       1203  北海道 小樽市        NaN   121623457   NaN
# 3  2018100000  2018年度       1204  北海道 旭川市        NaN   398298889   NaN
# 4  2018100000  2018年度       1205  北海道 室蘭市        NaN   102405024   NaN
#
#    num_of_sample  misc
# 0         878047   NaN
# 1         110159   NaN
# 2          47519   NaN
# 3         141786   NaN
# 4          35533   NaN

# %%
df.drop(['code', 'year','dist_name','momo'], axis=1, inplace=True)

# %%
df.drop(['misc'], axis=1,inplace=True)

# %%
df['mean_income'] = df['income']/df['num_of_sample']

# %%
df.head()
# Out:
#    dist_code  koumoku      income  num_of_sample  mean_income
# 0       1100  北海道 札幌市  2765204529         878047  3149.267100
# 1       1202  北海道 函館市   309138713         110159  2806.295564
# 2       1203  北海道 小樽市   121623457          47519  2559.470044
# 3       1204  北海道 旭川市   398298889         141786  2809.155269
# 4       1205  北海道 室蘭市   102405024          35533  2881.969549

# %%
tmm =df.sort_values(by='mean_income', ascending=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1741 entries, 0 to 1740
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dist_code      1741 non-null   int64
#  1   koumoku        1741 non-null   object
#  2   income         1741 non-null   int64
#  3   num_of_sample  1741 non-null   int64
#  4   mean_income    1741 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 68.1+ KB

# %%
pd.set_option('display.max_columns', 100)

# %%
tmm.head(50)
# Out:
#       dist_code   koumoku      income  num_of_sample   mean_income
# 629       13103    東京都 港区  1592760255         141396  11264.535454
# 627       13101  東京都 千代田区   362690825          36299   9991.758037
# 639       13113   東京都 渋谷区  1119013391         131459   8512.261549
# 112        1511   北海道 猿払村    10343833           1351   7656.427091
# 1161      28206   兵庫県 芦屋市   289990028          44417   6528.807168
# 628       13102   東京都 中央区   604855042          93465   6471.460354
# 636       13110   東京都 目黒区   982732740         159730   6152.461904
# 631       13105   東京都 文京区   738614951         120604   6124.298954
# 400        7545   福島県 大熊町    20224352           3597   5622.561023
# 638       13112  東京都 世田谷区  2708792374         488851   5541.141113
# 630       13104   東京都 新宿区   994411782         182956   5435.251000
# 652       13203  東京都 武蔵野市   414980302          77328   5366.494698
# 824       19424   山梨県 忍野村    23694723           4652   5093.448624
# ...
